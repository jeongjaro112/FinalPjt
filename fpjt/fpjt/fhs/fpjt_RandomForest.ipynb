# %%
import pandas as pd

stock_select = pd.read_csv('./stockInfo_20230609-100747.csv', encoding = 'utf-8')

# %%
stock_select
# Out:
#      EV_EBITDA    PBR    PER     ROE  \
# 0        25.46  11.42  33.95     NaN
# 1          NaN    NaN    NaN     NaN
# 2          NaN    NaN    NaN     NaN
# 3         5.62   3.50   8.44     NaN
# 4          NaN    NaN    NaN     NaN
# ...        ...    ...    ...     ...
# 2465      3.02   0.86   3.86   25.20
# 2466      1.87   0.46   2.56   20.56
# 2467  1,290.64   5.56    NaN  -22.55
# 2468      1.87   0.73  11.54    6.51
# 2469      8.20   1.04  26.12    4.21
#
#                                                     매출액  \
# 0     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 1     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 2                                                   NaN
# 3     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 4                                                   NaN
# ...                                                 ...
# 2465  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 2466  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 2467  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 2468  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 2469  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
#
#                                                   배당수익율  \
# 0        \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t
# 1        \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t
# 2                                                   NaN
# 3        \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t
# 4                                                   NaN
# ...                                                 ...
# 2465     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t
# 2466  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 2467     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t
# 2468  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...
# 2469     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t
#
#                                                    부채비율          상세구분    순이익  \
# 0     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...           화장품    173
# 1     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...          창업투자    NaN
# 2                                                   NaN            화학    NaN
# 3     \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...           핸드셋    169
# 4                                                   NaN          창업투자    NaN
# ...                                                 ...           ...    ...
# 2465  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...  섬유,의류,신발,호화품    767
# 2466  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...            철강  3,763
# 2467  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...            제약   -220
# 2468  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...            화학  1,462
# 2469  \n\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t...            화학  3,660
#
#         순이익율    시장구분   업종구분        종목명      종목코드  투자의견  \
# 0      16.98  KOSDAQ     화학       마녀공장  "439090"   NaN
# 1        NaN  KOSDAQ  금융서비스    하나27호스팩  "448370"   NaN
# 2        NaN   KOSPI     화학  이수스페셜티케미컬  "457190"   NaN
# 3      16.57  KOSDAQ    반도체         팸텍  "271830"   NaN
# 4        NaN  KOSDAQ  금융서비스    키움제8호스팩  "446840"   NaN
# ...      ...     ...    ...        ...       ...   ...
# 2465    5.23   KOSPI    유통업       신성통상  "005390"   NaN
# 2466    9.52   KOSPI  기타금융업     세아제강지주  "003030"   NaN
# 2467  -10.06   KOSPI    의약품       영진약품  "003520"   NaN
# 2468    5.93   KOSPI     화학     롯데정밀화학  "004000"  4.00
# 2469    2.68   KOSPI     화학      한화솔루션  "009830"  3.95
#
#                                             현재가
# 0      \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t41,600
# 1       \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t2,165
# 2     \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t228,000
# 3       \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t5,470
# 4       \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t2,140
# ...                                         ...
# 2465    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t2,060
# 2466  \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t172,000
# 2467    \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t2,730
# 2468   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t65,400
# 2469   \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t48,700
#
# [2470 rows x 16 columns]

# %%
import pandas as pd
import re

# 데이터프레임 불러오기
stock_select = pd.read_csv('./stockInfo_20230609-100747.csv', encoding='utf-8', thousands=',')

# 정규식 패턴
# pattern = re.compile(r'\d+\.?\d*')
pattern = re.compile(r'[\d,]+\.?\d*')

# 모든 칼럼에 적용하는 함수
def clean_cell(cell):
    cell = re.sub(r'[\r\n\t\s]', '', cell)  # 이스케이프 시퀀스 및 공백 제거
    if cell == '':
        return None
    numeric_value = pattern.findall(cell)  # 숫자 값 추출
    return numeric_value[0] if numeric_value else cell

# 데이터프레임의 모든 칼럼을 문자열로 변환
stock_select = stock_select.astype(str)

# 모든 칼럼에 함수 적용
stock_select = stock_select.applymap(clean_cell)

# 결과 확인
stock_select
# Out:
#      EV_EBITDA    PBR    PER    ROE      매출액 배당수익율    부채비율  상세구분     순이익  \
# 0        25.46  11.42  33.95    nan    1,018  None   20.40   화장품   173.0
# 1          nan    nan    nan    nan     None  None    None  창업투자     nan
# 2          nan    nan    nan    nan      nan   nan     nan    화학     nan
# 3         5.62    3.5   8.44    nan    1,019  None   62.10   핸드셋   169.0
# 4          nan    nan    nan    nan      nan   nan     nan  창업투자     nan
# ...        ...    ...    ...    ...      ...   ...     ...   ...     ...
# 2465      3.02   0.86   3.86   25.2   14,658  None  197.93     ,   767.0
# 2466      1.87   0.46   2.56  20.56   39,538  1.54   80.34    철강  3763.0
# 2467   1290.64   5.56    nan  22.55    2,184  None  125.97    제약   220.0
# 2468      1.87   0.73  11.54   6.51   24,638  6.17   18.12    화학  1462.0
# 2469       8.2   1.04  26.12   4.21  136,539  None  140.80    화학  3660.0
#
#        순이익율    시장구분   업종구분        종목명    종목코드  투자의견     현재가
# 0     16.98  KOSDAQ     화학       마녀공장  439090   nan   41600
# 1       nan  KOSDAQ  금융서비스         27  448370   nan    2165
# 2       nan   KOSPI     화학  이수스페셜티케미컬  457190   nan  228000
# 3     16.57  KOSDAQ    반도체         팸텍  271830   nan    5470
# 4       nan  KOSDAQ  금융서비스          8  446840   nan    2140
# ...     ...     ...    ...        ...     ...   ...     ...
# 2465   5.23   KOSPI    유통업       신성통상  005390   nan    2060
# 2466   9.52   KOSPI  기타금융업     세아제강지주  003030   nan  172000
# 2467  10.06   KOSPI    의약품       영진약품  003520   nan    2730
# 2468   5.93   KOSPI     화학     롯데정밀화학  004000   4.0   65400
# 2469   2.68   KOSPI     화학      한화솔루션  009830  3.95   48700
#
# [2470 rows x 16 columns]

# %%
stock_select['select'] = 0
stock_select['투자의견'] = pd.to_numeric(stock_select['투자의견'], errors='coerce')
stock_select.loc[stock_select.투자의견>3.5, 'select'] = 1

# %%
stock_select
# Out:
#      EV_EBITDA    PBR    PER    ROE      매출액 배당수익율    부채비율  상세구분     순이익  \
# 0        25.46  11.42  33.95    nan    1,018  None   20.40   화장품   173.0
# 1          nan    nan    nan    nan     None  None    None  창업투자     nan
# 2          nan    nan    nan    nan      nan   nan     nan    화학     nan
# 3         5.62    3.5   8.44    nan    1,019  None   62.10   핸드셋   169.0
# 4          nan    nan    nan    nan      nan   nan     nan  창업투자     nan
# ...        ...    ...    ...    ...      ...   ...     ...   ...     ...
# 2465      3.02   0.86   3.86   25.2   14,658  None  197.93     ,   767.0
# 2466      1.87   0.46   2.56  20.56   39,538  1.54   80.34    철강  3763.0
# 2467   1290.64   5.56    nan  22.55    2,184  None  125.97    제약   220.0
# 2468      1.87   0.73  11.54   6.51   24,638  6.17   18.12    화학  1462.0
# 2469       8.2   1.04  26.12   4.21  136,539  None  140.80    화학  3660.0
#
#        순이익율    시장구분   업종구분        종목명    종목코드  투자의견     현재가  select
# 0     16.98  KOSDAQ     화학       마녀공장  439090   NaN   41600       0
# 1       nan  KOSDAQ  금융서비스         27  448370   NaN    2165       0
# 2       nan   KOSPI     화학  이수스페셜티케미컬  457190   NaN  228000       0
# 3     16.57  KOSDAQ    반도체         팸텍  271830   NaN    5470       0
# 4       nan  KOSDAQ  금융서비스          8  446840   NaN    2140       0
# ...     ...     ...    ...        ...     ...   ...     ...     ...
# 2465   5.23   KOSPI    유통업       신성통상  005390   NaN    2060       0
# 2466   9.52   KOSPI  기타금융업     세아제강지주  003030   NaN  172000       0
# 2467  10.06   KOSPI    의약품       영진약품  003520   NaN    2730       0
# 2468   5.93   KOSPI     화학     롯데정밀화학  004000  4.00   65400       1
# 2469   2.68   KOSPI     화학      한화솔루션  009830  3.95   48700       1
#
# [2470 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split

X = stock_select[['EV_EBITDA', 'PBR', 'PER', 'ROE', '배당수익율','부채비율']]
y = stock_select.select
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=123)

# %%
#!pip install statsmodels

# %%
# import statsmodels.api as sm
# X1 = sm.add_constant(X_train)
# logit_model = sm.Logit(y_train, X1)
# result = logit_model.fit()
# result.summary()

# %%
import pandas as pd
import re
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# 데이터프레임 불러오기
stock_select = pd.read_csv('./stockInfo_20230609-100747.csv', encoding='utf-8', thousands=',')

# 정규식 패턴
pattern = re.compile(r'[\d,]+\.?\d*')

# 모든 칼럼에 적용하는 함수
def clean_cell(cell):
    cell = re.sub(r'[\r\n\t\s]', '', str(cell))  # 이스케이프 시퀀스 및 공백 제거
    if cell == '':
        return None
    numeric_value = pattern.findall(cell)  # 숫자 값 추출
    return numeric_value[0] if numeric_value else cell

# 모든 칼럼에 함수 적용
stock_select = stock_select.applymap(clean_cell)

# 결측값 처리
stock_select = stock_select.fillna(0)  # 결측값을 0으로 대체하거나

# 유형 변환
stock_select['투자의견'] = pd.to_numeric(stock_select['투자의견'], errors='coerce')

# 'select' 컬럼 초기화
stock_select['select'] = 0

# 'select' 값 설정
stock_select.loc[stock_select['투자의견'] > 3.5, 'select'] = 1

# 모델 적합을 위한 데이터 준비
X = stock_select[['EV_EBITDA', 'PBR', 'PER', 'ROE', '배당수익율', '부채비율']]
y = stock_select['select']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# 데이터 유형 변환
X_train = X_train.replace('-', np.nan)
X_train = X_train.replace(',', '', regex=True).replace('inf', np.nan).astype(float)
X_train = X_train.fillna(0)

X_test = X_test.replace('-', np.nan)
X_test = X_test.replace(',', '', regex=True).replace('inf', np.nan).astype(float)
X_test = X_test.fillna(0)

# 모델 적합
X1 = sm.add_constant(X_train)
logit_model = sm.Logit(y_train, X1)
result = logit_model.fit()

# 결과 출력
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.503308
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 select   No. Observations:                 1729
# Model:                          Logit   Df Residuals:                     1722
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 16 Jun 2023   Pseudo R-squ.:                 0.03341
# Time:                        20:56:29   Log-Likelihood:                -870.22
# converged:                       True   LL-Null:                       -900.30
# Covariance Type:            nonrobust   LLR p-value:                 4.182e-11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5530      0.088    -17.670      0.000      -1.725      -1.381
# EV_EBITDA  -7.242e-05      0.000     -0.422      0.673      -0.000       0.000
# PBR           -0.0042      0.003     -1.348      0.178      -0.010       0.002
# PER            0.0004      0.000      1.492      0.136      -0.000       0.001
# ROE           -0.0044      0.003     -1.630      0.103      -0.010       0.001
# 배당수익율          0.1740      0.029      5.966      0.000       0.117       0.231
# 부채비율           0.0006      0.000      2.911      0.004       0.000       0.001
# ==============================================================================

# %%
import pandas as pd
import re
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# 데이터프레임 불러오기
stock_select = pd.read_csv('./stockInfo_20230609-100747.csv', encoding='utf-8', thousands=',')

# 정규식 패턴
pattern = re.compile(r'[\d,]+\.?\d*')

# 모든 칼럼에 적용하는 함수
def clean_cell(cell):
    cell = re.sub(r'[\r\n\t\s]', '', str(cell))  # 이스케이프 시퀀스 및 공백 제거
    if cell == '':
        return None
    numeric_value = pattern.findall(cell)  # 숫자 값 추출
    return numeric_value[0] if numeric_value else cell

# 모든 칼럼에 함수 적용
stock_select = stock_select.applymap(clean_cell)

# 결측값 처리
stock_select = stock_select.fillna(0)  # 결측값을 0으로 대체하거나

# 유형 변환
stock_select['투자의견'] = pd.to_numeric(stock_select['투자의견'], errors='coerce')

# 'select' 컬럼 초기화
stock_select['select'] = 0

# 'select' 값 설정
stock_select.loc[stock_select['투자의견'] > 3.5, 'select'] = 1

# 모델 적합을 위한 데이터 준비
X = stock_select[['EV_EBITDA', 'PBR', 'PER', 'ROE', '배당수익율', '부채비율']]
y = stock_select['select']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# 데이터 유형 변환
X_train = X_train.replace('-', np.nan)
X_train = X_train.replace(',', '', regex=True).replace('inf', np.nan).astype(float)
X_train = X_train.fillna(0)

X_test = X_test.replace('-', np.nan)
X_test = X_test.replace(',', '', regex=True).replace('inf', np.nan).astype(float)
X_test = X_test.fillna(0)

# 모델 적합
X1 = sm.add_constant(X_train)
logit_model = sm.Logit(y_train, X1)
result = logit_model.fit()

# 결과 출력
print(result.summary())

# 통계적 가설 검정
# 각 독립 변수의 계수에 대한 가설 검정 수행
# 예시: EV_EBITDA 독립 변수의 가중치에 대한 가설 검정
hypothesis = "EV_EBITDA = 0"  # 검정할 가설 설정
t_test = result.t_test(hypothesis)
print("\nEV_EBITDA 가중치에 대한 가설 검정")
print("t-value:", t_test.tvalue[0])
print("p-value:", t_test.pvalue.item())

# 변수 선택
# 예시: 변수 선택 알고리즘을 사용하여 중요한 독립 변수 선택
selected_variables = ['EV_EBITDA', 'PBR', 'ROE']
X_selected = X_train[selected_variables]
X_selected = sm.add_constant(X_selected)
logit_model_selected = sm.Logit(y_train, X_selected)
result_selected = logit_model_selected.fit()
print("\n선택된 변수에 대한 모델 결과")
print(result_selected.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.503308
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 select   No. Observations:                 1729
# Model:                          Logit   Df Residuals:                     1722
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 16 Jun 2023   Pseudo R-squ.:                 0.03341
# Time:                        21:12:12   Log-Likelihood:                -870.22
# converged:                       True   LL-Null:                       -900.30
# Covariance Type:            nonrobust   LLR p-value:                 4.182e-11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.5530      0.088    -17.670      0.000      -1.725      -1.381
# EV_EBITDA  -7.242e-05      0.000     -0.422      0.673      -0.000       0.000
# PBR           -0.0042      0.003     -1.348      0.178      -0.010       0.002
# PER            0.0004      0.000      1.492      0.136      -0.000       0.001
# ROE           -0.0044      0.003     -1.630      0.103      -0.010       0.001
# 배당수익율          0.1740      0.029      5.966      0.000       0.117       0.231
# 부채비율           0.0006      0.000      2.911      0.004       0.000       0.001
# ==============================================================================
#
# EV_EBITDA 가중치에 대한 가설 검정
# t-value: [-0.422142]
# p-value: 0.6729213767113246
# Optimization terminated successfully.
#          Current function value: 0.518844
#          Iterations 7
#
# 선택된 변수에 대한 모델 결과
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 select   No. Observations:                 1729
# Model:                          Logit   Df Residuals:                     1725
# Method:                           MLE   Df Model:                            3
# Date:                Fri, 16 Jun 2023   Pseudo R-squ.:                0.003574
# Time:                        21:12:12   Log-Likelihood:                -897.08
# converged:                       True   LL-Null:                       -900.30
# Covariance Type:            nonrobust   LLR p-value:                   0.09223
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.2094      0.070    -17.167      0.000      -1.348      -1.071
# EV_EBITDA     -0.0002      0.000     -0.854      0.393      -0.001       0.000
# PBR            0.0006      0.003      0.173      0.863      -0.006       0.007
# ROE           -0.0048      0.003     -1.768      0.077      -0.010       0.001
# ==============================================================================

# %%
import pandas as pd
import re
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# 데이터프레임 불러오기
stock_select = pd.read_csv('./stockInfo_20230609-100747.csv', encoding='utf-8', thousands=',')

# 정규식 패턴
pattern = re.compile(r'[\d,]+\.?\d*')

# 모든 칼럼에 적용하는 함수
def clean_cell(cell):
    cell = re.sub(r'[\r\n\t\s]', '', str(cell))  # 이스케이프 시퀀스 및 공백 제거
    if cell == '':
        return None
    numeric_value = pattern.findall(cell)  # 숫자 값 추출
    return numeric_value[0] if numeric_value else cell

# 모든 칼럼에 함수 적용
stock_select = stock_select.applymap(clean_cell)

# 결측값 처리
stock_select = stock_select.fillna(0)  # 결측값을 0으로 대체하거나

# 유형 변환
stock_select['투자의견'] = pd.to_numeric(stock_select['투자의견'], errors='coerce')

# 'select' 컬럼 초기화
stock_select['select'] = 0

# 'select' 값 설정
stock_select.loc[stock_select['투자의견'] > 3.5, 'select'] = 1

# 모델 적합을 위한 데이터 준비
X = stock_select[['EV_EBITDA', 'PBR', 'PER', 'ROE', '배당수익율', '부채비율']]
y = stock_select['select']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# 데이터 유형 변환
X_train = X_train.replace('-', np.nan)
X_train = X_train.replace(',', '', regex=True).replace('inf', np.nan).astype(float)
X_train = X_train.fillna(0)

X_test = X_test.replace('-', np.nan)
X_test = X_test.replace(',', '', regex=True).replace('inf', np.nan).astype(float)
X_test = X_test.fillna(0)

# 모델 적합
X_train = sm.add_constant(X_train)  # 상수항 추가
linear_model = sm.OLS(y_train, X_train)  # 선형 회귀 모델
result = linear_model.fit()  # 모델 적합

# 결과 출력
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 select   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     11.25
# Date:                Fri, 23 Jun 2023   Prob (F-statistic):           2.36e-12
# Time:                        16:24:41   Log-Likelihood:                -882.45
# No. Observations:                1729   AIC:                             1779.
# Df Residuals:                    1722   BIC:                             1817.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1649      0.013     13.118      0.000       0.140       0.190
# EV_EBITDA   -7.21e-06   2.14e-05     -0.338      0.736   -4.91e-05    3.47e-05
# PBR           -0.0009      0.000     -2.075      0.038      -0.002      -5e-05
# PER         9.586e-05   5.67e-05      1.692      0.091   -1.53e-05       0.000
# ROE           -0.0003      0.000     -1.698      0.090      -0.001    4.49e-05
# 배당수익율          0.0331      0.005      6.852      0.000       0.024       0.043
# 부채비율           0.0001   3.34e-05      3.491      0.000    5.12e-05       0.000
# ==============================================================================
# Omnibus:                      305.665   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              496.786
# Skew:                           1.313   Prob(JB):                    1.33e-108
# Kurtosis:                       3.021   Cond. No.                         610.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# R-squared(결정 계수): 이 값은 모델이 종속 변수의 변동성을 얼마나 잘 설명하는지 나타냄. 
# R-squared 값은 0과 1 사이의 범위에서 변동하며, 1에 가까울수록 모델이 종속 변수의 변동성을 잘 설명. 
# 위의 경우, R-squared 값은 0.038로 매우 낮다. 즉, 독립 변수들이 종속 변수의 변동성을 매우 약하게 
# 설명하고 있다.

# Adj. R-squared(조정 결정 계수): R-squared 값을 보정한 값으로, 독립 변수의 수와 샘플의 크기를 
# 고려하여 모델의 설명력을 보다 정확하게 평가함. Adj. R-squared 값도 0과 1 사이의 범위에서 변동하며, \
# 위의 경우 0.034로 매우 낮다.

# F-statistic: 회귀 모델의 유의성을 평가하는 값이다. F-statistic 값이 클수록 모델의 유의성이 높다. 
# 위의 경우 F-statistic 값은 11.25로, 유의성이 있는 모델이다. Prob (F-statistic) 값은 F-statistic에 대한 p-value를 나타내며, 
# 이 값이 매우 작은 것을 보아 유의미한 모델이라고 할 수 있다.

# 회귀 계수(coef): 각 독립 변수의 회귀 계수 값과 해당 계수의 통계적 유의성에 대한 정보가 제공된다. 
# 회귀 계수는 해당 독립 변수가 종속 변수에 미치는 영향을 나타내며, 계수가 양수이면 해당 독립 변수가 
# 종속 변수를 증가시키는 영향을 가지고, 음수이면 감소시키는 영향을 가진다고 해석할 수 있습니다. 

# P>|t| 값은 회귀 계수의 통계적 유의성에 대한 p-value를 나타내며, 일반적으로 0.05보다 작으면 통계적으로 유의미한 계수다.

# Omnibus, Prob(Omnibus), Jarque-Bera (JB), Skew, Kurtosis: 이는 회귀 모델의 잔차(residual)에 대한 
# 정규성과 대칭성에 대한 검정 결과를 제공한다. 이 값들은 회귀 모델의 가정을 평가하는 데 사용됩니다.

# Durbin-Watson: 이 값은 회귀 모델의 잔차 사이에 자기 상관(autocorrelation)이 존재하는지를 평가합니다. 
# 값이 2에 가까울수록 자기 상관이 존재하지 않는다는 가정을 만족한다.

# Cond. No.: 이 값은 다중공선성(multicollinearity)의 정도를 나타내는 조건수(condition number)입니다. 
# 조건수가 큰 경우 다중공선성이 존재할 수 있으며, 이는 독립 변수들 사이에 강한 상관관계가 있음을 의미.

# 위의 결과를 종합하면, 주어진 독립 변수들이 종속 변수를 설명하는 데 매우 약한 영향을 가지고 있으며, 
# 모델의 설명력은 매우 낮다. 또한, 회귀계수 중 일부는 통계적으로 유의미한 것으로 나타나지만, 다른 독립변수들의 
# 회귀계수는 유의미하지 않다. 유의미한 것으로 나타난 독립 변수는 'PBR', '배당수익율' 및 '부채비율'이다. 
# 이 독립 변수들은 p-value가 0.05보다 작으므로, 통계적으로 유의미한 영향을 가지고 있다고 할 수 있다. 
# 다른 독립 변수들인 'EV_EBITDA', 'PER', 'ROE'의 경우에는 p-value가 0.05보다 크므로, 
# 통계적으로 유의미한 영향을 가지지 않는 것으로 판단해야 한다.
# 모델의 잔차에 대한 정규성과 대칭성 검정에서는 이상이 없는 것으로 
# 나타났고, 자기 상관이 없는 것으로 판단됨. 
# 결론적으로, 주어진 선형 회귀 모델은 주가수익율을 설명하는 데 유의미한 결과를 도출하지 못했으며, 
# 다른 모델이나 독립 변수들의 조합을 고려해볼 필요가 있다.
